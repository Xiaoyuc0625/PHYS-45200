# %% [markdown]
# <a href="https://colab.research.google.com/github/Xiaoyuc0625/PHYS-45200/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
print("Hello World")
print(np.arange(0,1,0.2))
# Out:
# Hello World
# [0.  0.2 0.4 0.6 0.8]
